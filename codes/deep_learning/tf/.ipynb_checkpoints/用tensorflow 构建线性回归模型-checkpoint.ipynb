# %%
import tensorflow as tf
import numpy as np

# %%
# 使用numpy 生成100个随机点
x_data = np.random.rand(100)
y_data = x_data * 0.1 + 0.2
print(10 * x_data)
# Out:
# [9.14726229 3.62174093 1.03181752 2.41695993 2.47154948 6.61215261
#  3.47108244 6.70793207 7.99613087 2.90001179 6.49694114 8.58603962
#  1.4971669  0.29090997 5.8053101  1.69331888 1.35945348 1.91296989
#  5.41257878 3.63194133 6.99681899 5.0665962  4.5392757  8.85800039
#  4.55847365 9.95568693 0.00999517 7.01331991 5.73794819 8.34768634
#  2.7123059  5.31162035 4.73675137 0.5771211  9.33215804 6.27564464
#  9.6774169  7.28365135 1.15709158 5.62094235 1.75279204 0.93854202
#  6.70860742 2.59422489 4.71484989 3.21971079 1.10887346 0.46863614
#  8.66407795 7.4841414  7.31921278 2.06885599 5.79756719 5.12362446
#  3.75826397 5.14501019 6.9400562  4.73302582 8.6904068  4.97200118
#  4.34281337 3.42843803 1.5880234  0.35214225 6.70580808 4.99881011
#  1.69878567 3.33734809 2.98640694 4.26969543 2.50712759 7.60668601
#  9.92921441 5.56604618 8.83513422 4.67278085 4.11548972 0.31236767
#  3.20547935 1.39558687 2.34991901 6.39016077 5.66920533 9.15363088
#  6.56712573 4.56758273 5.23693227 2.37860848 4.32948411 6.32719117
#  9.47483619 5.28760301 8.78153557 5.90580354 4.2439912  6.7879531
#  8.13505687 0.51837339 8.866565   1.28756705]

# %%
# 构造一个线性模型
b = tf.Variable(0.)
k = tf.Variable(0.)

y = k * x_data + b

# 定义一个二次代价函数 loss function mean square error
# reduce_mean 就是求平均值
loss = tf.reduce_mean(tf.square(y_data - y))

# 定义一个用梯度下降法来训练的优化器, 学习率为0.2, 通过梯度下降法确定参数k和b
optimizer = tf.train.GradientDescentOptimizer(0.2)

# 训练的目的是为了最小化代价函数
train = optimizer.minimize(loss)

# 初始化变量
init = tf.global_variables_initializer()

with tf.Session() as sess:
    sess.run(init)
    for step in range(2201):
        sess.run(train)
        if step % 200 == 0:
            print(step, sess.run([k, b]))
# Out:
# (0, [0.050937545, 0.099325895])
# (200, [0.10001745, 0.19999103])
# (400, [0.10000021, 0.19999988])
# (600, [0.10000021, 0.19999988])
# (800, [0.10000021, 0.19999988])
# (1000, [0.10000021, 0.19999988])
# (1200, [0.10000021, 0.19999988])
# (1400, [0.10000021, 0.19999988])
# (1600, [0.10000021, 0.19999988])
# (1800, [0.10000021, 0.19999988])
# (2000, [0.10000021, 0.19999988])
# (2200, [0.10000021, 0.19999988])
